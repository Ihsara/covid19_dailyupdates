# %%
import sys, os 

import pandas as pd

# %%
excel_base = pd.ExcelFile('../data/COVID-19-geographic-disbtribution-worldwide-2020-03-17.xlsx')
df = pd.read_excel(excel_base, 'COVID-19-geographic-disbtributi')

# %%
df
# Out:
#         DateRep  Day  Month  Year  Cases  Deaths Countries and territories  \
# 0    2020-03-17   17      3  2020      5       0               Afghanistan
# 1    2020-03-16   16      3  2020      6       0               Afghanistan
# 2    2020-03-15   15      3  2020      3       0               Afghanistan
# 3    2020-03-11   11      3  2020      3       0               Afghanistan
# 4    2020-03-08    8      3  2020      3       0               Afghanistan
# ...         ...  ...    ...   ...    ...     ...                       ...
# 5383 2020-01-04    4      1  2020      0       0                   Vietnam
# 5384 2020-01-03    3      1  2020      0       0                   Vietnam
# 5385 2020-01-02    2      1  2020      0       0                   Vietnam
# 5386 2020-01-01    1      1  2020      0       0                   Vietnam
# 5387 2019-12-31   31     12  2019      0       0                   Vietnam
#
#      GeoId
# 0       AF
# 1       AF
# 2       AF
# 3       AF
# ...

# %%
vn_df = df[df.GeoId == 'VN']

# %%
vn_df
# Out:
#         DateRep  Day  Month  Year  Cases  Deaths Countries and territories  \
# 5314 2020-03-17   17      3  2020      4       0                   Vietnam
# 5315 2020-03-16   16      3  2020      4       0                   Vietnam
# 5316 2020-03-15   15      3  2020      4       0                   Vietnam
# 5317 2020-03-14   14      3  2020      5       0                   Vietnam
# 5318 2020-03-13   13      3  2020      5       0                   Vietnam
# ...         ...  ...    ...   ...    ...     ...                       ...
# 5383 2020-01-04    4      1  2020      0       0                   Vietnam
# 5384 2020-01-03    3      1  2020      0       0                   Vietnam
# 5385 2020-01-02    2      1  2020      0       0                   Vietnam
# 5386 2020-01-01    1      1  2020      0       0                   Vietnam
# 5387 2019-12-31   31     12  2019      0       0                   Vietnam
#
#      GeoId
# 5314    VN
# 5315    VN
# 5316    VN
# 5317    VN
# ...

# %%
fi_df = df[df.GeoId == 'FI']

# %%
fi_df
# Out:
#         DateRep  Day  Month  Year  Cases  Deaths Countries and territories  \
# 1678 2020-03-17   17      3  2020      5       0                   Finland
# 1679 2020-03-16   16      3  2020     57       0                   Finland
# 1680 2020-03-15   15      3  2020     55       0                   Finland
# 1681 2020-03-13   13      3  2020     96       0                   Finland
# 1682 2020-03-12   12      3  2020     19       0                   Finland
# ...         ...  ...    ...   ...    ...     ...                       ...
# 1746 2020-01-04    4      1  2020      0       0                   Finland
# 1747 2020-01-03    3      1  2020      0       0                   Finland
# 1748 2020-01-02    2      1  2020      0       0                   Finland
# 1749 2020-01-01    1      1  2020      0       0                   Finland
# 1750 2019-12-31   31     12  2019      0       0                   Finland
#
#      GeoId
# 1678    FI
# 1679    FI
# 1680    FI
# 1681    FI
# ...
